# %% [markdown]
# # Basic Data Types

# %% [markdown]
# ## Defining a variable

# %%
x=5
print(x)
# Out:
# 5

# %%
x = 'Ryan'
print(x)
# Out:
# Ryan

# %%
1x
# Out:
#   Cell In[6], line 1
#     1x
#     ^
# SyntaxError: invalid decimal literal

# %%
type(x)
# Out:
# str

# %% [markdown]
# ## Numbers

# %%
type(1.5)
# Out:
# float

# %%
type(2j)
# Out:
# complex

# %%
1j * 1j
# Out:
# (-1+0j)

# %% [markdown]
# where j is an imaginary unit

# %% [markdown]
# ## Strings

# %%
'String 1 ' + 'String 2'
# Out:
# 'String 1 String 2'

# %% [markdown]
# the action of concatenation

# %%
'1' + '1'
# Out:
# '11'

# %% [markdown]
# ^strings are not numbers

# %%
1 + '1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 1 + '1'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
true = True

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %% [markdown]
# '==' comparison operator
