# %% [markdown]
# # Ints and FLoats

# %%
20/4
# Out:
# 5.0

# %%
4 + 4.0
# Out:
# 8.0

# %%
4 * 4.0
# Out:
# 16.0

# %%
4 ** 4.0
# Out:
# 256.0

# %%
int(4 ** 4.0)

#int in this case is a class as well are lists, floats, strings
#programmers call it casting: 'Casting from the float 256 to the integer 256'
# Out:
# 256

# %%
int(8.9)

#when casting from a float to an int, Python does not round for you.
# Out:
# 8

# %%
round(44/9, 2)

#amount of decimal places after a coma
# Out:
# 4.89
