# %% [markdown]
# ## Functions

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
def multiplybyThree(val):
    return 3 * val

multiplybyThree(4)
# Out:
# 12

# %%
def multiply(val1, val2):
    return val1 * val2

multiply(3,4)
# Out:
# 12

# %% [markdown]
# Functions do not necessarily need to return anything

# %%
a = [1,2,3]

def appendFour (myList):
    myList.append(4)

appendFour(a)
print(a)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# The function above did not return anything because you do not always want it popped back up at you

# %%
print(print('Hello, World!'))
# Out:
# Hello, World!
# None

# %% [markdown]
# Print function actually returns none and none is a special python keyword - absence of value, NoneType
