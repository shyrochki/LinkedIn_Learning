# %% [markdown]
# # Bytes

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
#the b in front differentiate it from a regular string

# %%
smileyBytes = bytes('😊', 'utf-8')
smileyBytes
# Out:
# b'\xf0\x9f\x98\x8a'

# %%
smileyBytes.decode('utf-8')
# Out:
# '😊'

# %% [markdown]
# UTF-8 is a universal dictionary, it includes every language and emojis

# %%
smileyBytes = bytearray('😔', 'utf-8')

# %%
smileyBytes
# Out:
# bytearray(b'\xf0\x9f\x98\x94')

# %%
smileyBytes[3] = int('75',16)

# %%
smileyBytes.decode('utf-8')
# Out:
# '😅'
